# %% [markdown]
# ## 地址空间
#
# 实现地址空间的第一步就是实现分页机制，建立好虚拟内存和物理内存的页映射关系。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# no address dependency for the user program
#
# - the user program link start address is no limited.

# %% [markdown]
# ### Rust 中的动态内存分配
#
# #### memory allocation
#
# - static memory allocation
#   - lifetime all the time
#   - no fragmentation
#   - memory utilization is low
# - dynamic memory allocation `Heap`
#   - variable lifetime controlled by the program, maybe cause memory leak
#   - fragmentation when more time malloc and free

# %% [markdown]
# #### Rust heap data structure
